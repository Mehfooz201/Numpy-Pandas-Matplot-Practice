# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as nps

# %%
try:
    data = pd.read_csv('DataSets and Books/astronauts.csv')
    print('OK')
except:
    print('File Mising')
# Out:
# OK

# %%
data.shape
# Out:
# (357, 19)

# %%
data.ndim
# Out:
# 2

# %%
data.head(2) #By-Default 5 Record
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# ...

# %%
data.tail(3) #Last three Records
# Out:
#                  Name    Year  Group   Status Birth Date        Birth Place  \
# 354  Alfred M. Worden  1966.0    5.0  Retired   2/7/1932        Jackson, MI
# 355     John W. Young  1962.0    2.0  Retired  9/24/1930  San Francisco, CA
# 356   George D. Zamka  1998.0   17.0  Retired  6/29/1962    Jersey City, NJ
#
#     Gender                                         Alma Mater  \
# 354   Male        US Military Academy; University of Michigan
# 355   Male                    Georgia Institute of Technology
# 356   Male  US Naval Academy; Florida Institute of Technology
#
#           Undergraduate Major                            Graduate Major  \
# 354          Military Science  Aeronautical & Astronautical Engineering
# 355  Aeronautical Engineering                                       NaN
# 356               Mathematics                    Engineering Management
#
#     Military Rank            Military Branch  Space Flights  \
# ...

# %%
data.sample(10)
# Out:
#                        Name    Year  Group    Status  Birth Date  \
# 124        Owen K. Garriott  1965.0    4.0   Retired  11/22/1930
# 298     William M. Shepherd  1984.0   10.0   Retired   7/26/1949
# 222       William C. McCool  1996.0   16.0  Deceased   9/23/1961
# 63         Roger B. Chaffee  1963.0    3.0  Deceased   2/15/1935
# 331          Rex J. Walheim  1996.0   16.0    Active  10/10/1962
# 329           James S. Voss  1987.0   12.0   Retired    3/3/1949
# 346     Jeffrey N. Williams  1996.0   16.0    Active   1/18/1958
# 94         Bonnie J. Dunbar  1980.0    9.0   Retired    3/3/1949
# 310     Kathryn D. Sullivan  1978.0    8.0   Retired   10/3/1951
# 148  Bernard A. Harris Jr.   1990.0   13.0   Retired   6/26/1956
#
#           Birth Place  Gender  \
# 124          Enid, OK    Male
# 298     Oak Ridge, TN    Male
# 222     San Diego, CA    Male
# 63   Grand Rapids, MI    Male
# 331       Redwood, CA    Male
# 329       Cordova, AL    Male
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
data.rename(columns={'Birth Date':'birht_date', 'BirthPlace':'birth_place', 'Alma Mater': 'alma_mater', 'Undergraduate Major' :'undergratuate_major', 'Graduate Major':'graduate_major',
       'Military Rank':'military_rank', 'Military Branch':'military_branch', 'Space Flights':'space_flights',
       'Space Flight (hr)':'space_filght(hr)', 'Space Walks':'space_walks', 'Space Walks (hr)':'space_walks(hr)',
       'Death Date':'death_date', 'Death Mission':'death_mission'}, inplace=True)

# %%
data.head(1)
# Out:
#               Name    Year  Group  Status birht_date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0  Active  5/17/1967  Inglewood, CA   Male
#
#                                           alma_mater undergratuate_major  \
# 0  University of California-Santa Barbara; Univer...             Geology
#
#   graduate_major military_rank military_branch  space_flights  \
# 0        Geology           NaN             NaN              2
#
#    space_filght(hr)  space_walks  space_walks(hr)  \
# 0              3307            2             13.0
#
#                                  Missions death_date death_mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   birht_date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   alma_mater           356 non-null    object
#  8   undergratuate_major  335 non-null    object
#  9   graduate_major       298 non-null    object
#  10  military_rank        207 non-null    object
#  11  military_branch      211 non-null    object
#  12  space_flights        357 non-null    int64
#  13  space_filght(hr)     357 non-null    int64
#  14  space_walks          357 non-null    int64
# ...

# %%
data[data.death_mission.notnull()]
# Out:
#                      Name    Year  Group    Status  birht_date  \
# 10    Michael P. Anderson  1995.0   15.0  Deceased  12/25/1959
# 42         David M. Brown  1996.0   16.0  Deceased   4/16/1956
# 63       Roger B. Chaffee  1963.0    3.0  Deceased   2/15/1935
# 67         Kalpana Chawla  1995.0   15.0  Deceased    6/1/1961
# 70        Laurel B. Clark  1996.0   16.0  Deceased   3/10/1961
# 140     Virgil I. Grissom  1959.0    1.0  Deceased    4/3/1926
# 170       Rick D. Husband  1995.0   15.0  Deceased   7/12/1957
# 173     Gregory B. Jarvis     NaN    NaN  Deceased   8/24/1944
# 219  S. Christa McAuliffe     NaN    NaN  Deceased    9/2/1948
# 222     William C. McCool  1996.0   16.0  Deceased   9/23/1961
# 226      Ronald E. McNair  1978.0    8.0  Deceased  10/21/1950
# 250    Ellison S. Onizuka  1978.0    8.0  Deceased   6/24/1946
# 271      Judith A. Resnik  1978.0    8.0  Deceased    4/5/1949
# 287     Francis R. Scobee  1978.0    8.0  Deceased   5/19/1939
# ...

# %%
data.isnull()
# Out:
#       Name   Year  Group  Status  birht_date  Birth Place  Gender  alma_mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
data.notnull()
# Out:
#      Name   Year  Group  Status  birht_date  Birth Place  Gender  alma_mater  \
# 0    True   True   True    True        True         True    True        True
# 1    True  False  False    True        True         True    True        True
# 2    True   True   True    True        True         True    True        True
# 3    True   True   True    True        True         True    True        True
# 4    True   True   True    True        True         True    True        True
# ..    ...    ...    ...     ...         ...          ...     ...         ...
# 352  True   True   True    True        True         True    True        True
# 353  True   True   True    True        True         True    True        True
# 354  True   True   True    True        True         True    True        True
# 355  True   True   True    True        True         True    True        True
# 356  True   True   True    True        True         True    True        True
#
# ...

# %%
data[data.notnull()] #This is called mask
# Out:
#                       Name    Year  Group   Status birht_date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# birht_date               0
# Birth Place              0
# Gender                   0
# alma_mater               1
# undergratuate_major     22
# graduate_major          59
# military_rank          150
# military_branch        146
# space_flights            0
# space_filght(hr)         0
# space_walks              0
# space_walks(hr)          0
# Missions                23
# death_date             305
# death_mission          341
# dtype: int64

# %%
data.Year = pd.to_datetime(data.Year)
data.Year
# Out:
# 0     1970-01-01 00:00:00.000002004
# 1                               NaT
# 2     1970-01-01 00:00:00.000001984
# 3     1970-01-01 00:00:00.000001987
# 4     1970-01-01 00:00:00.000001963
#                    ...
# 352   1970-01-01 00:00:00.000001990
# 353   1970-01-01 00:00:00.000001998
# 354   1970-01-01 00:00:00.000001966
# 355   1970-01-01 00:00:00.000001962
# 356   1970-01-01 00:00:00.000001998
# Name: Year, Length: 357, dtype: datetime64[ns]

# %%
data.birht_date = pd.to_datetime(data.birht_date)
data.birht_date
# Out:
# 0     1967-05-17
# 1     1936-03-07
# 2     1946-03-03
# 3     1951-05-20
# 4     1930-01-20
#          ...
# 352   1956-08-23
# 353   1962-07-26
# 354   1932-02-07
# 355   1930-09-24
# 356   1962-06-29
# Name: birht_date, Length: 357, dtype: datetime64[ns]

# %%
data.death_date = pd.to_datetime(data.death_date)
data.death_date
# Out:
# 0     NaT
# 1     NaT
# 2     NaT
# 3     NaT
# 4     NaT
#        ..
# 352   NaT
# 353   NaT
# 354   NaT
# 355   NaT
# 356   NaT
# Name: death_date, Length: 357, dtype: datetime64[ns]

# %%
data.head(1)
# Out:
#               Name                          Year  Group  Status birht_date  \
# 0  Joseph M. Acaba 1970-01-01 00:00:00.000002004   19.0  Active 1967-05-17
#
#      Birth Place Gender                                         alma_mater  \
# 0  Inglewood, CA   Male  University of California-Santa Barbara; Univer...
#
#   undergratuate_major graduate_major military_rank military_branch  \
# 0             Geology        Geology           NaN             NaN
#
#    space_flights  space_filght(hr)  space_walks  space_walks(hr)  \
# 0              2              3307            2             13.0
#
#                                  Missions death_date death_mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN

# %%
data[~data.isnull()]
# Out:
#                       Name                          Year  Group   Status  \
# 0          Joseph M. Acaba 1970-01-01 00:00:00.000002004   19.0   Active
# 1           Loren W. Acton                           NaT    NaN  Retired
# 2         James C. Adamson 1970-01-01 00:00:00.000001984   10.0  Retired
# 3          Thomas D. Akers 1970-01-01 00:00:00.000001987   12.0  Retired
# 4              Buzz Aldrin 1970-01-01 00:00:00.000001963    3.0  Retired
# ..                     ...                           ...    ...      ...
# 352          David A. Wolf 1970-01-01 00:00:00.000001990   13.0  Retired
# 353  Neil W. Woodward III  1970-01-01 00:00:00.000001998   17.0  Retired
# 354       Alfred M. Worden 1970-01-01 00:00:00.000001966    5.0  Retired
# 355          John W. Young 1970-01-01 00:00:00.000001962    2.0  Retired
# 356        George D. Zamka 1970-01-01 00:00:00.000001998   17.0  Retired
#
#     birht_date        Birth Place Gender  \
# 0   1967-05-17      Inglewood, CA   Male
# ...

# %%
data[data.Year.notnull()]
# Out:
#                       Name                          Year  Group   Status  \
# 0          Joseph M. Acaba 1970-01-01 00:00:00.000002004   19.0   Active
# 2         James C. Adamson 1970-01-01 00:00:00.000001984   10.0  Retired
# 3          Thomas D. Akers 1970-01-01 00:00:00.000001987   12.0  Retired
# 4              Buzz Aldrin 1970-01-01 00:00:00.000001963    3.0  Retired
# 5          Andrew M. Allen 1970-01-01 00:00:00.000001987   12.0  Retired
# ..                     ...                           ...    ...      ...
# 352          David A. Wolf 1970-01-01 00:00:00.000001990   13.0  Retired
# 353  Neil W. Woodward III  1970-01-01 00:00:00.000001998   17.0  Retired
# 354       Alfred M. Worden 1970-01-01 00:00:00.000001966    5.0  Retired
# 355          John W. Young 1970-01-01 00:00:00.000001962    2.0  Retired
# 356        George D. Zamka 1970-01-01 00:00:00.000001998   17.0  Retired
#
#     birht_date        Birth Place Gender  \
# 0   1967-05-17      Inglewood, CA   Male
# ...

# %% [markdown]
# # Handling Missing Values
#     - Filling Missing Values
#     - Dropping Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    datetime64[ns]
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   birht_date           357 non-null    datetime64[ns]
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   alma_mater           356 non-null    object
#  8   undergratuate_major  335 non-null    object
#  9   graduate_major       298 non-null    object
#  10  military_rank        207 non-null    object
#  11  military_branch      211 non-null    object
#  12  space_flights        357 non-null    int64
#  13  space_filght(hr)     357 non-null    int64
#  14  space_walks          357 non-null    int64
# ...

# %%
# data.Year.fillna(data.Year.mode().mean())
data.Year.isnull().sum()
# Out:
# 27

# %%
data.Year.fillna(data.Year.mode(), inplace=True)

# %%
data.Year
# Out:
# 0     1970-01-01 00:00:00.000002004
# 1     1970-01-01 00:00:00.000001996
# 2     1970-01-01 00:00:00.000001984
# 3     1970-01-01 00:00:00.000001987
# 4     1970-01-01 00:00:00.000001963
#                    ...
# 352   1970-01-01 00:00:00.000001990
# 353   1970-01-01 00:00:00.000001998
# 354   1970-01-01 00:00:00.000001966
# 355   1970-01-01 00:00:00.000001962
# 356   1970-01-01 00:00:00.000001998
# Name: Year, Length: 357, dtype: datetime64[ns]

# %%
data.Year.isnull().sum()
# Out:
# 26

# %%
data.Year.mode()
# Out:
# 0   1970-01-01 00:00:00.000001996
# dtype: datetime64[ns]

# %%
data.fillna({'Year': data.Year.mode(),
             'Group': data.Group.mode(),
             'alma_mater': data.alma_mater.mode(),
             'undergratuate_major': data.undergratuate_major.mode(),
             'graduate_major' : data.graduate_major.mode(),
             
            })

data.head(1)
# Out:
#               Name                          Year  Group  Status birht_date  \
# 0  Joseph M. Acaba 1970-01-01 00:00:00.000002004   19.0  Active 1967-05-17
#
#      Birth Place Gender                                         alma_mater  \
# 0  Inglewood, CA   Male  University of California-Santa Barbara; Univer...
#
#   undergratuate_major graduate_major military_rank military_branch  \
# 0             Geology        Geology           NaN             NaN
#
#    space_flights  space_filght(hr)  space_walks  space_walks(hr)  \
# 0              2              3307            2             13.0
#
#                                  Missions death_date death_mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN

# %%
# data.fillna()
data.dropna()

# %%
try:
    data = pd.read_csv('DataSets and Books/grouping.xlsx')
    print('OK')
except:
    print('File Mising')
# Out:
# File Mising
